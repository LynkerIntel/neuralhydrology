# %%
import pickle
from pathlib import Path

import matplotlib.pyplot as plt
import torch
from neuralhydrology.evaluation import metrics
from neuralhydrology.nh_run import start_run, eval_run

# %%
# by default we assume that you have at least one CUDA-capable NVIDIA GPU
if torch.cuda.is_available():
#    start_run(config_file=Path("./config_files/co_basins.yml"))
#    start_run(config_file=Path("./config_files/1_hydroatlas_basin.yml"))
    start_run(config_file=Path("./config_files/30_hydroatlas_basin.yml"))

# fall back to CPU-only mode
else:
#    start_run(config_file=Path("./config_files/co_basins.yml"), gpu=-1)
#    start_run(config_file=Path("./config_files/1_hydroatlas_basin.yml"), gpu=-1)
    start_run(config_file=Path("./config_files/30_hydroatlas_basin.yml"), gpu=-1)
# Out:
# 2024-06-11 14:41:41,463: Logging to /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/2023_colorado_swe/runs/test_run_30_colorado_hydroatlas_basin_1106_144141/output.log initialized.
# 2024-06-11 14:41:41,465: ### Folder structure created at /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/2023_colorado_swe/runs/test_run_30_colorado_hydroatlas_basin_1106_144141
# 2024-06-11 14:41:41,465: ### Run configurations for test_run_30_colorado_hydroatlas_basin
# 2024-06-11 14:41:41,466: experiment_name: test_run_30_colorado_hydroatlas_basin
# 2024-06-11 14:41:41,467: train_basin_file: basin_txt_files/30_hydroatlas_basin.txt
# 2024-06-11 14:41:41,467: validation_basin_file: basin_txt_files/30_hydroatlas_basin.txt
# 2024-06-11 14:41:41,468: test_basin_file: basin_txt_files/30_hydroatlas_basin.txt
# 2024-06-11 14:41:41,468: train_start_date: 1980-10-01 00:00:00
# 2024-06-11 14:41:41,469: train_end_date: 1999-09-30 00:00:00
# 2024-06-11 14:41:41,469: validation_start_date: 2003-10-01 00:00:00
# 2024-06-11 14:41:41,470: validation_end_date: 2004-09-30 00:00:00
# 2024-06-11 14:41:41,470: test_start_date: 2006-10-01 00:00:00
# 2024-06-11 14:41:41,471: test_end_date: 2007-09-30 00:00:00
# 2024-06-11 14:41:41,471: device: cpu
# 2024-06-11 14:41:41,472: validate_every: 1
# 2024-06-11 14:41:41,472: validate_n_random_basins: 1
# 2024-06-11 14:41:41,473: metrics: ['NSE']
# 2024-06-11 14:41:41,473: model: cudalstm
# 2024-06-11 14:41:41,473: head: regression
# 2024-06-11 14:41:41,474: output_activation: linear
# 2024-06-11 14:41:41,480: hidden_size: 20
# 2024-06-11 14:41:41,484: initial_forget_bias: 3
# 2024-06-11 14:41:41,487: output_dropout: 0.4
# 2024-06-11 14:41:41,489: optimizer: Adam
# 2024-06-11 14:41:41,490: loss: MSE
# 2024-06-11 14:41:41,491: learning_rate: {0: 0.01, 30: 0.005, 40: 0.001}
# 2024-06-11 14:41:41,494: batch_size: 256
# 2024-06-11 14:41:41,494: epochs: 10
# 2024-06-11 14:41:41,495: clip_gradient_norm: 1
# 2024-06-11 14:41:41,495: predict_last_n: 1
# 2024-06-11 14:41:41,496: seq_length: 365
# 2024-06-11 14:41:41,496: num_workers: 8
# 2024-06-11 14:41:41,497: log_interval: 5
# 2024-06-11 14:41:41,497: log_tensorboard: True
# 2024-06-11 14:41:41,497: log_n_figures: 10
# 2024-06-11 14:41:41,498: save_weights_every: 15
# 2024-06-11 14:41:41,498: dataset: colorado_swe
# 2024-06-11 14:41:41,499: data_dir: ../data
# 2024-06-11 14:41:41,500: forcings: ['nldas']
# 2024-06-11 14:41:41,501: dynamic_inputs: ['dswrfsfc', 'pressfc', 'tmp2m_max', 'tmp2m_min']
# 2024-06-11 14:41:41,502: target_variables: ['apcpsfc']
# 2024-06-11 14:41:41,503: clip_targets_to_zero: ['apcpsfc']
# 2024-06-11 14:41:41,504: number_of_basins: 30
# 2024-06-11 14:41:41,505: run_dir: /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/2023_colorado_swe/runs/test_run_30_colorado_hydroatlas_basin_1106_144141
# 2024-06-11 14:41:41,505: train_dir: /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/2023_colorado_swe/runs/test_run_30_colorado_hydroatlas_basin_1106_144141/train_data
# 2024-06-11 14:41:41,506: img_log_dir: /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/2023_colorado_swe/runs/test_run_30_colorado_hydroatlas_basin_1106_144141/img_log
# 2024-06-11 14:41:41,516: ### Device cpu will be used for training
# 2024-06-11 14:41:41,517: Loading basin data into xarray data set.
# 100%|██████████| 30/30 [05:39<00:00, 11.31s/it]
# 2024-06-11 14:47:20,862: Create lookup table and convert to pytorch tensor
# 100%|██████████| 30/30 [00:01<00:00, 21.07it/s]
# # Epoch 1:   0%|          | 0/814 [00:00<?, ?it/s]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:   0%|          | 1/814 [00:25<5:46:36, 25.58s/it, Loss: 0.7694]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:   0%|          | 1/814 [00:25<5:46:36, 25.58s/it, Loss: 0.5772]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:   0%|          | 3/814 [00:25<1:30:44,  6.71s/it, Loss: 0.2611]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:   0%|          | 3/814 [00:25<1:30:44,  6.71s/it, Loss: 1.1295]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:   1%|          | 5/814 [00:26<44:46,  3.32s/it, Loss: 0.3315]  Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:   1%|          | 6/814 [00:26<33:05,  2.46s/it, Loss: 0.3311]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:   1%|          | 7/814 [00:26<24:18,  1.81s/it, Loss: 0.2772]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:   1%|          | 7/814 [00:26<24:18,  1.81s/it, Loss: 0.4849]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:   1%|          | 9/814 [00:26<14:07,  1.05s/it, Loss: 0.3061]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:   1%|          | 10/814 [00:26<11:03,  1.21it/s, Loss: 0.3307]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:   1%|▏         | 11/814 [00:26<08:34,  1.56it/s, Loss: 0.8092]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:   1%|▏         | 11/814 [00:26<08:34,  1.56it/s, Loss: 0.6089]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:   2%|▏         | 13/814 [00:26<05:29,  2.43it/s, Loss: 0.2548]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:   2%|▏         | 14/814 [00:26<04:35,  2.90it/s, Loss: 0.4617]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:   2%|▏         | 15/814 [00:27<03:47,  3.51it/s, Loss: 0.4426]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:   2%|▏         | 16/814 [00:27<03:08,  4.23it/s, Loss: 0.3604]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:   2%|▏         | 17/814 [00:27<02:39,  4.98it/s, Loss: 0.4857]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:
Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 10:  98%|█████████▊| 797/814 [02:29<00:02,  5.97it/s, Loss: 0.2539]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 10:  98%|█████████▊| 798/814 [02:29<00:02,  5.83it/s, Loss: 0.4942]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 10:  98%|█████████▊| 799/814 [02:29<00:02,  5.90it/s, Loss: 0.3005]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 10:  98%|█████████▊| 800/814 [02:30<00:02,  5.76it/s, Loss: 0.2841]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 10:  98%|█████████▊| 801/814 [02:30<00:02,  5.50it/s, Loss: 0.2951]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 10:  99%|█████████▊| 802/814 [02:30<00:02,  5.46it/s, Loss: 0.3940]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 10:  99%|█████████▊| 803/814 [02:30<00:01,  5.77it/s, Loss: 0.2463]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 10:  99%|█████████▉| 804/814 [02:30<00:01,  5.89it/s, Loss: 0.2551]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 10:  99%|█████████▉| 805/814 [02:30<00:01,  6.19it/s, Loss: 0.3470]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 10:  99%|█████████▉| 806/814 [02:31<00:01,  6.37it/s, Loss: 0.1575]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 10:  99%|█████████▉| 807/814 [02:31<00:01,  6.50it/s, Loss: 0.2186]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 10:  99%|█████████▉| 808/814 [02:31<00:00,  6.50it/s, Loss: 0.2114]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 10:  99%|█████████▉| 809/814 [02:31<00:00,  6.31it/s, Loss: 0.2722]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 10: 100%|█████████▉| 810/814 [02:31<00:00,  6.33it/s, Loss: 0.3508]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 10: 100%|█████████▉| 811/814 [02:31<00:00,  6.34it/s, Loss: 0.3071]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 10: 100%|█████████▉| 812/814 [02:31<00:00,  6.34it/s, Loss: 0.2367]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 10: 100%|█████████▉| 813/814 [02:32<00:00,  6.27it/s, Loss: 0.3888]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 10: 100%|██████████| 814/814 [02:33<00:00,  5.32it/s, Loss: 0.5524]
# 2024-06-11 15:11:48,456: Epoch 10 average loss: avg_loss: 0.28168, avg_total_loss: 0.28168
# # Validation: 100%|██████████| 1/1 [00:12<00:00, 12.21s/it]
# 2024-06-11 15:12:00,857: Epoch 10 average validation loss: 0.59021 -- Median validation metrics: avg_loss: 0.59021, NSE: 0.26866

# %%
thislinewillstopthenotebookfromrunning
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 thislinewillstopthenotebookfromrunning
#
# NameError: name 'thislinewillstopthenotebookfromrunning' is not defined

# %% [markdown]
# ### Evaluate run on test set
# The run directory that needs to be specified for evaluation is printed in the output log above. Since the folder name is created dynamically (including the date and time of the start of the run) you will need to change the `run_dir` argument according to your local directory name. By default, it will use the same device as during the training process.

# %%
run_dir = Path("runs/test_run_30_colorado_hydroatlas_basin_1106_095251")
#eval_run(run_dir=run_dir, period="test")

eval_run(run_dir=run_dir, period="train")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 4
#       1 run_dir = Path("runs/test_run_30_colorado_hydroatlas_basin_1106_095251")
#       2 #eval_run(run_dir=run_dir, period="test")
# ----> 4 eval_run(run_dir=run_dir, period="train")
#
# File ~/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/nh_run.py:169, in eval_run(run_dir, period, epoch, gpu)
#     166 if gpu is not None and gpu < 0:
#     167     config.device = "cpu"
# --> 169 start_evaluation(cfg=config, run_dir=run_dir, epoch=epoch, period=period)
#
# File ~/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/evaluation/evaluate.py:23, in start_evaluation(cfg, run_dir, epoch, period)
#       8 """Start evaluation of a trained network
#       9
#      10 Parameters
#    (...)
#      20
#      21 """
#      22 tester = get_tester(cfg=cfg, run_dir=run_dir, period=period, init_model=True)
# ---> 23 tester.evaluate(epoch=epoch, save_results=True, save_all_output=cfg.save_all_output, metrics=cfg.metrics)
#
# File ~/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/evaluation/tester.py:177, in BaseTester.evaluate(self, epoch, save_results, save_all_output, metrics, model, experiment_logger)
#     175 if model is None:
#     176     if self.init_model:
# --> 177         self._load_weights(epoch=epoch)
#     178         model = self.model
#     179     else:
#
# File ~/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/evaluation/tester.py:130, in BaseTester._load_weights(self, epoch)
#     128 def _load_weights(self, epoch: int = None):
#     129     """Load weights of a certain (or the last) epoch into the model."""
# --> 130     weight_file = self._get_weight_file(epoch)
#     132     LOGGER.info(f"Using the model weights from {weight_file}")
#     133     self.model.load_state_dict(torch.load(weight_file, map_location=self.device))
#
# File ~/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/evaluation/tester.py:122, in BaseTester._get_weight_file(self, epoch)
#     120 """Get file path to weight file"""
#     121 if epoch is None:
# --> 122     weight_file = sorted(list(self.run_dir.glob('model_epoch*.pt')))[-1]
#     123 else:
#     124     weight_file = self.run_dir / f"model_epoch{str(epoch).zfill(3)}.pt"
#
# IndexError: list index out of range

# %% [markdown]
# ### Load and inspect model predictions
# Next, we load the results file and compare the model predictions with observations. The results file is always a pickled dictionary with one key per basin (even for a single basin). The next-lower dictionary level is the temporal resolution of the predictions. In this case, we trained a model only on daily data ('1D'). Within the temporal resolution, the next-lower dictionary level are `xr`(an xarray Dataset that contains observations and predictions), as well as one key for each metric that was specified in the config file.

# %%
with open(run_dir / "test" / "model_epoch050" / "test_results.p", "rb") as fp:
    results = pickle.load(fp)
    
results.keys()

# %% [markdown]
# The data variables in the xarray Dataset are named according to the name of the target variables, with suffix `_obs` for the observations and suffix `_sim` for the simulations.

# %%
example_test_basin = '06614800'

# %%
results[example_test_basin]['1D']['xr']

# %% [markdown]
# Let's plot the model predictions vs. the observations

# %%
# extract observations and simulations
qobs = results[example_test_basin]['1D']['xr']['QObs(mm/d)_obs']
qsim = results[example_test_basin]['1D']['xr']['QObs(mm/d)_sim']

fig, ax = plt.subplots(figsize=(8,5))
ax.plot(qobs['date'], qobs, label="streamflow observation")
ax.plot(qsim['date'], qsim, label="LSTM prediction")
plt.legend()
ax.set_ylabel("Discharge (mm/d)")
ax.set_title(f"Test period on basin {example_test_basin} - NSE {results[example_test_basin]['1D']['NSE']:.3f}")
plt.show()
plt.close()

# %% [markdown]
# Next, we are going to compute all metrics that are implemented in the NeuralHydrology package. You will find additional hydrological signatures implemented in `neuralhydrology.evaluation.signatures`.

# %%
values = metrics.calculate_all_metrics(qobs.isel(time_step=-1), qsim.isel(time_step=-1))
for key, val in values.items():
    print(f"{key}: {val:.3f}")
