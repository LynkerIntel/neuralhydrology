# %%
import pickle
from pathlib import Path
import matplotlib.pyplot as plt
import torch
from neuralhydrology.evaluation import metrics
from neuralhydrology.nh_run import start_run, eval_run
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %% [markdown]
# # train model

# %%
#run_config_file = "../../config_files/pretrain/pretrain_snotel.yml"   # 531 - CO camels basins with snotel
#run_config_file = "../../config_files/test/colorado_snotel.yml"    # 15 colorado camels basins with snotel
run_config_file = "../../config_files/test/test_generic_data.yml"    # 15 colorado camels basins with snotel, using generic datasetzoo

print('training: ' + run_config_file)

# Check if MPS backend is available
if torch.backends.mps.is_available():
    mps_device = torch.device("mps")
    print("Using MPS backend")
    
    # Start training with MPS backend
    start_run(config_file=Path(run_config_file))

# Fall back to CUDA if available
elif torch.cuda.is_available():
    print("Using CUDA backend")
    
    # Start training with CUDA backend
    start_run(config_file=Path(run_config_file))

# Fall back to CPU-only mode
else:
    print("Using CPU backend")
    
    # Start training with CPU backend
    start_run(config_file=Path(run_config_file), gpu=-1)
# Out:
# training: ../../config_files/test/test_generic_data.yml
# Using MPS backend
# 2024-06-19 14:48:23,487: Logging to /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/nasa_co_swe/job_scripts/test/runs/test_generic_data_1906_144823/output.log initialized.
# 2024-06-19 14:48:23,487: ### Folder structure created at /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/nasa_co_swe/job_scripts/test/runs/test_generic_data_1906_144823
# 2024-06-19 14:48:23,488: ### Run configurations for test_generic_data
# 2024-06-19 14:48:23,488: experiment_name: test_generic_data
# 2024-06-19 14:48:23,489: train_basin_file: ../../basin_txt_files/co_camels_basins.v1.txt
# 2024-06-19 14:48:23,489: validation_basin_file: ../../basin_txt_files/co_camels_basins.v1.txt
# 2024-06-19 14:48:23,490: test_basin_file: ../../basin_txt_files/co_camels_basins.v1.txt
# 2024-06-19 14:48:23,490: seed: 5
# 2024-06-19 14:48:23,491: train_start_date: 2000-10-01 00:00:00
# 2024-06-19 14:48:23,492: train_end_date: 2009-09-30 00:00:00
# 2024-06-19 14:48:23,492: validation_start_date: 2009-10-01 00:00:00
# 2024-06-19 14:48:23,493: validation_end_date: 2010-09-30 00:00:00
# 2024-06-19 14:48:23,493: test_start_date: 2010-10-01 00:00:00
# 2024-06-19 14:48:23,493: test_end_date: 2014-09-30 00:00:00
# 2024-06-19 14:48:23,494: device: mps
# 2024-06-19 14:48:23,494: validate_every: 1
# 2024-06-19 14:48:23,495: validate_n_random_basins: 1000
# 2024-06-19 14:48:23,495: metrics: ['NSE', 'KGE', 'Alpha-NSE', 'Beta-NSE', 'Pearson-r', 'RMSE', 'Peak-Timing']
# 2024-06-19 14:48:23,495: model: cudalstm
# 2024-06-19 14:48:23,496: head: regression
# 2024-06-19 14:48:23,496: output_activation: linear
# 2024-06-19 14:48:23,497: hidden_size: 128
# 2024-06-19 14:48:23,497: initial_forget_bias: 3
# 2024-06-19 14:48:23,497: output_dropout: 0.4
# 2024-06-19 14:48:23,498: optimizer: Adam
# 2024-06-19 14:48:23,498: loss: MSE
# 2024-06-19 14:48:23,499: learning_rate: {0: 0.001, 1: 0.0005, 2: 0.0001, 3: 5e-05}
# 2024-06-19 14:48:23,499: batch_size: 256
# 2024-06-19 14:48:23,500: epochs: 20
# 2024-06-19 14:48:23,500: clip_gradient_norm: 1
# 2024-06-19 14:48:23,500: predict_last_n: 1
# 2024-06-19 14:48:23,501: seq_length: 365
# 2024-06-19 14:48:23,501: num_workers: 12
# 2024-06-19 14:48:23,502: log_interval: 5
# 2024-06-19 14:48:23,502: log_tensorboard: True
# 2024-06-19 14:48:23,502: log_n_figures: 1
# 2024-06-19 14:48:23,503: save_weights_every: 1
# 2024-06-19 14:48:23,503: dataset: generic
# 2024-06-19 14:48:23,504: data_dir: ../../../data/nasa_co_swe
# 2024-06-19 14:48:23,504: dynamic_inputs: ['cape', 'crainf_fra', 'lwdown', 'psurf', 'qair', 'rainf', 'swdown', 'tair_max', 'tair_min', 'wind_e', 'wind_n', 'mean_co_swe']
# 2024-06-19 14:48:23,504: target_variables: ['QObs']
# 2024-06-19 14:48:23,505: clip_targets_to_zero: ['QObs']
# 2024-06-19 14:48:23,505: static_attributes: ['prm_pc_sse', 'cly_pc_sav', 'slt_pc_sav', 'snd_pc_sav', 'soc_th_sav', 'kar_pc_sse', 'lka_pc_sse', 'gwt_cm_sav', 'slp_dg_sav', 'ele_mt_sav', 'snw_pc_syr', 'PC1', 'PC2']
# 2024-06-19 14:48:23,505: number_of_basins: 14
# 2024-06-19 14:48:23,506: run_dir: /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/nasa_co_swe/job_scripts/test/runs/test_generic_data_1906_144823
# 2024-06-19 14:48:23,506: train_dir: /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/nasa_co_swe/job_scripts/test/runs/test_generic_data_1906_144823/train_data
# 2024-06-19 14:48:23,506: img_log_dir: /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/nasa_co_swe/job_scripts/test/runs/test_generic_data_1906_144823/img_log
# 2024-06-19 14:48:23,512: ### Device cpu will be used for training
# 2024-06-19 14:48:23,572: Loading basin data into xarray data set.
# 100%|██████████| 14/14 [00:00<00:00, 38.23it/s]
# 2024-06-19 14:48:23,955: Create lookup table and convert to pytorch tensor
# 100%|██████████| 14/14 [00:00<00:00, 26.22it/s]
# 2024-06-19 14:48:24,657: Setting learning rate to 0.0005
# # Epoch 1:   0%|          | 0/160 [00:00<?, ?it/s]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:   1%|          | 1/160 [00:32<1:26:44, 32.74s/it, Loss: 0.7536]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:   1%|▏         | 2/160 [00:33<36:31, 13.87s/it, Loss: 0.7614]  Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:   2%|▏         | 3/160 [00:34<20:30,  7.84s/it, Loss: 0.3114]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:   2%|▎         | 4/160 [00:34<12:59,  5.00s/it, Loss: 0.3354]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:   3%|▎         | 5/160 [00:35<08:49,  3.42s/it, Loss: 0.5134]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:   4%|▍         | 6/160 [00:35<06:20,  2.47s/it, Loss: 0.4735]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:   4%|▍         | 7/160 [00:36<04:48,  1.89s/it, Loss: 0.7878]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:   5%|▌         | 8/160 [00:37<03:46,  1.49s/it, Loss: 0.2996]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:   6%|▌         | 9/160 [00:37<03:04,  1.22s/it, Loss: 0.5260]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:   6%|▋         | 10/160 [00:38<02:35,  1.03s/it, Loss: 0.3358]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:   7%|▋         | 11/160 [00:39<02:15,  1.10it/s, Loss: 0.2865]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:   8%|▊         | 12/160 [00:39<02:01,  1.22it/s, Loss: 0.4315]Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# # Epoch 1:
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)

# %% [markdown]
# ### Evaluate run on test set
# The run directory that needs to be specified for evaluation is printed in the output log above. Since the folder name is created dynamically (including the date and time of the start of the run) you will need to change the `run_dir` argument according to your local directory name. By default, it will use the same device as during the training process.

# %%
#run_dir = Path("./runs/co_basins_QObs_antecedent")
run_dir = Path("./runs/test_generic_data_1906_144823/")
print(run_dir)

eval_run(run_dir=run_dir, period="test")
eval_run(run_dir=run_dir, period="train")
eval_run(run_dir=run_dir, period="validation")
# Out:
# runs/test_generic_data_1906_144823
# # Evaluation:   7%|▋         | 1/14 [00:01<00:22,  1.77s/it]
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# # Evaluation:  14%|█▍        | 2/14 [00:02<00:17,  1.44s/it]
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# # Evaluation:  21%|██▏       | 3/14 [00:04<00:14,  1.34s/it]
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# # Evaluation:  29%|██▊       | 4/14 [00:05<00:12,  1.28s/it]
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# # Evaluation:  36%|███▌      | 5/14 [00:06<00:11,  1.25s/it]
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# # Evaluation:  43%|████▎     | 6/14 [00:07<00:09,  1.21s/it]
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# # Evaluation:  50%|█████     | 7/14 [00:08<00:08,  1.22s/it]
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# # Evaluation:  57%|█████▋    | 8/14 [00:10<00:07,  1.19s/it]
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# # Evaluation:  64%|██████▍   | 9/14 [00:11<00:05,  1.19s/it]
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# # Evaluation:  71%|███████▏  | 10/14 [00:12<00:04,  1.16s/it]
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# # Evaluation:  79%|███████▊  | 11/14 [00:13<00:03,  1.14s/it]
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# # Evaluation:  86%|████████▌ | 12/14 [00:14<00:02,  1.14s/it]
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# # Evaluation:  93%|█████████▎| 13/14 [00:15<00:01,  1.14s/it]
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# # Evaluation: 100%|██████████| 14/14 [00:16<00:00,  1.21s/it]
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# # Evaluation:   7%|▋         | 1/14 [00:02<00:32,  2.50s/it]
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# # Evaluation:  14%|█▍        | 2/14 [00:05<00:30,  2.50s/it]
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# # Evaluation:  21%|██▏       | 3/14 [00:07<00:27,  2.48s/it]
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# # Evaluation:  29%|██▊       | 4/14 [00:09<00:25,  2.50s/it]
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# # Evaluation:  36%|███▌      | 5/14 [00:12<00:22,  2.48s/it]
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# # Evaluation:  43%|████▎     | 6/14 [00:14<00:19,  2.46s/it]
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# # Evaluation:  50%|█████     | 7/14 [00:17<00:17,  2.49s/it]
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# # Evaluation:  57%|█████▋    | 8/14 [00:19<00:14,  2.50s/it]
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# # Evaluation:  64%|██████▍   | 9/14 [00:22<00:12,  2.50s/it]
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# # Evaluation:  71%|███████▏  | 10/14 [00:24<00:09,  2.48s/it]
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# # Evaluation:  79%|███████▊  | 11/14 [00:27<00:07,  2.51s/it]
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# # Evaluation:  86%|████████▌ | 12/14 [00:30<00:05,  2.56s/it]
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# # Evaluation:  93%|█████████▎| 13/14 [00:32<00:02,  2.55s/it]
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# # Evaluation: 100%|██████████| 14/14 [00:35<00:00,  2.51s/it]
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# # Validation:   7%|▋         | 1/14 [00:00<00:05,  2.58it/s]
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# # Validation:  14%|█▍        | 2/14 [00:00<00:04,  2.57it/s]
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# # Validation:  21%|██▏       | 3/14 [00:01<00:04,  2.63it/s]
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# # Validation:  29%|██▊       | 4/14 [00:01<00:03,  2.58it/s]
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# # Validation:  36%|███▌      | 5/14 [00:01<00:03,  2.62it/s]
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# # Validation:  43%|████▎     | 6/14 [00:02<00:03,  2.62it/s]
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# # Validation:  50%|█████     | 7/14 [00:02<00:02,  2.62it/s]
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# # Validation:  57%|█████▋    | 8/14 [00:03<00:02,  2.57it/s]
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# # Validation:  64%|██████▍   | 9/14 [00:03<00:01,  2.61it/s]
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# # Validation:  71%|███████▏  | 10/14 [00:03<00:01,  2.61it/s]
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# # Validation:  79%|███████▊  | 11/14 [00:04<00:01,  2.63it/s]
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# # Validation:  86%|████████▌ | 12/14 [00:04<00:00,  2.62it/s]
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# # Validation:  93%|█████████▎| 13/14 [00:04<00:00,  2.65it/s]
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
# # Validation: 100%|██████████| 14/14 [00:05<00:00,  2.62it/s]
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)

# %% [markdown]
# ### Load and inspect model predictions
# Next, we load the results file and compare the model predictions with observations. The results file is always a pickled dictionary with one key per basin (even for a single basin). The next-lower dictionary level is the temporal resolution of the predictions. In this case, we trained a model only on daily data ('1D'). Within the temporal resolution, the next-lower dictionary level are `xr`(an xarray Dataset that contains observations and predictions), as well as one key for each metric that was specified in the config file.

# %%
period = 'test'
print('opening data for period: ' + period)

if period == 'train':
    
    with open(run_dir / "train" / "model_epoch020" / "train_results.p", "rb") as fp:
        results = pickle.load(fp)
        
    results.keys()

if period == 'test':
    with open(run_dir / "test" / "model_epoch020" / "test_results.p", "rb") as fp:
        results = pickle.load(fp)
        
    results.keys()
# Out:
# opening data for period: test

# %% [markdown]
# The data variables in the xarray Dataset are named according to the name of the target variables, with suffix `_obs` for the observations and suffix `_sim` for the simulations.

# %% [markdown]
# Let's plot the model predictions vs. the observations

# %%
for basin_id, basin_data in results.items():
    print(f"Processing basin ID: {basin_id}")
    
    # Access the xarray dataset for this basin
    #xr_ds = basin_data['1D']['xr']
    qobs = basin_data['1D']['xr']['QObs_obs']
    qsim = basin_data['1D']['xr']['QObs_sim']
    NSE = basin_data['1D']['NSE']
    
    # plot
    fig, ax = plt.subplots(figsize=(8,5))
    ax.plot(qobs['date'], qobs, label="streamflow observation")
    ax.plot(qsim['date'], qsim, label="LSTM prediction")
    plt.legend()
    ax.set_ylabel("Discharge (mm/d)")
    ax.set_title(f"{period} period on basin {basin_id} - NSE {NSE:.3f}")
    plt.show()
    plt.close()
    #break
# Out:
# Processing basin ID: 06614800
# Processing basin ID: 06746095
# Processing basin ID: 07083000
# Processing basin ID: 09034900
# Processing basin ID: 09035800
# Processing basin ID: 09035900
# Processing basin ID: 09047700
# Processing basin ID: 09065500
# Processing basin ID: 09066000
# Processing basin ID: 09066200
# Processing basin ID: 09066300
# Processing basin ID: 09081600
# Processing basin ID: 09107000
# Processing basin ID: 09352900

# %% [markdown]
# Next, we are going to compute all metrics that are implemented in the NeuralHydrology package. You will find additional hydrological signatures implemented in `neuralhydrology.evaluation.signatures`.

# %%
values = metrics.calculate_all_metrics(qobs.isel(time_step=-1), qsim.isel(time_step=-1))
for key, val in values.items():
    print(f"{key}: {val:.3f}")
# Out:
# NSE: 0.647
# MSE: 1.338
# RMSE: 1.157
# KGE: 0.801
# Alpha-NSE: 0.932
# Beta-KGE: 0.985
# Beta-NSE: -0.011
# Pearson-r: 0.813
# FHV: -13.500
# FMS: 2.606
# FLV: -1469.946
# Peak-Timing: 0.857
# Peak-MAPE: 55.579
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /Users/joshsturtevant/Documents/lynker/projects/nasa_water/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
