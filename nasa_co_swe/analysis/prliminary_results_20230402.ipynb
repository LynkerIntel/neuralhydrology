# %%
import os
import pickle
import numpy as np
import pandas as pd
import xarray as xr
import fnmatch
import matplotlib.pyplot as plt
import seaborn as sns

# %%
RUN_DIR = "./runs/preliminary_20240402/"
FILE_EX = "/test/model_epoch050/test_results.p"

# %%
# Define your lists
site_ids = ["06614800", "06746095", "07083000", "09034900", "09035800", "09035900", "09047700", "09065500", "09066000", "09066200", "09066300", "09081600", "09107000", "09306242", "09352900"]
model_types = ["co_swe_snotel", "co_swe_ua", "noSWE"]
seeds = ["0", "1", "2"]

# %%
# Initialize a dictionary to store your data
data_dict = {}

# Function to load a pickle file
def load_pickle(file_path):
    with open(file_path, 'rb') as f:
        return pickle.load(f)

# Iterate through site IDs, model types, and seeds
for site_id in site_ids:
    if site_id not in data_dict:
        data_dict[site_id] = {}
    
    for model_type in model_types:
        if model_type not in data_dict[site_id]:
            data_dict[site_id][model_type] = {}
        
        for seed in seeds:
            # Generate the file name pattern
            file_pattern = f"prelim_{site_id}_{model_type}_seed{seed}"
            
            # Find all files matching the pattern
            for filename in os.listdir(RUN_DIR):
                #if fnmatch.fnmatch(filename, file_pattern):
                if file_pattern in filename:
                    print("We have a match", filename, file_pattern)
                    file_path = os.path.join(RUN_DIR, filename)
                    # Load data from pickle file
                    pickle_data = load_pickle(f"{file_path}{FILE_EX}")
                    
                    # Extract the xarray Dataset
                    xr_dataset = pickle_data[site_id]['1D']['xr']
                    
                    # You can now access 'QObs(mm/d)_obs' and 'QObs(mm/d)_sim' from xr_dataset
                    # For example, to get 'QObs(mm/d)_obs' and 'QObs(mm/d)_sim':
                    qobs_obs = xr_dataset['QObs(mm/d)_obs']
                    qobs_sim = xr_dataset['QObs(mm/d)_sim']
                    
                    # Store the time series data in your dictionary
                    # Assuming seed is unique per model_type per site, hence directly assigning
                    data_dict[site_id][model_type][seed] = {
                        "QObs(mm/d)_obs": qobs_obs,
                        "QObs(mm/d)_sim": qobs_sim,
                        "NSE": pickle_data[site_id]['1D']['NSE']
                    }

# At this point, data_dict contains all the loaded data organized as required.
# You can now proceed to calculate metrics, perform ensemble analysis, and plot the data as needed.
# Out:
# We have a match prelim_06614800_co_swe_snotel_seed0_0304_084651 prelim_06614800_co_swe_snotel_seed0
# We have a match prelim_06614800_co_swe_snotel_seed1_0304_084817 prelim_06614800_co_swe_snotel_seed1
# We have a match prelim_06614800_co_swe_snotel_seed2_0304_084945 prelim_06614800_co_swe_snotel_seed2
# We have a match prelim_06614800_co_swe_ua_seed0_0104_162941 prelim_06614800_co_swe_ua_seed0
# We have a match prelim_06614800_co_swe_ua_seed1_0104_163333 prelim_06614800_co_swe_ua_seed1
# We have a match prelim_06614800_co_swe_ua_seed2_0104_163727 prelim_06614800_co_swe_ua_seed2
# We have a match prelim_06614800_noSWE_seed0_0104_163046 prelim_06614800_noSWE_seed0
# We have a match prelim_06614800_noSWE_seed1_0104_163438 prelim_06614800_noSWE_seed1
# We have a match prelim_06614800_noSWE_seed2_0104_163834 prelim_06614800_noSWE_seed2
# We have a match prelim_06746095_co_swe_snotel_seed0_0304_085112 prelim_06746095_co_swe_snotel_seed0
# We have a match prelim_06746095_co_swe_snotel_seed1_0304_085238 prelim_06746095_co_swe_snotel_seed1
# We have a match prelim_06746095_co_swe_snotel_seed2_0304_085406 prelim_06746095_co_swe_snotel_seed2
# We have a match prelim_06746095_co_swe_ua_seed0_0104_164125 prelim_06746095_co_swe_ua_seed0
# We have a match prelim_06746095_co_swe_ua_seed1_0104_164520 prelim_06746095_co_swe_ua_seed1
# We have a match prelim_06746095_co_swe_ua_seed2_0104_164910 prelim_06746095_co_swe_ua_seed2
# We have a match prelim_06746095_noSWE_seed0_0104_164232 prelim_06746095_noSWE_seed0
# We have a match prelim_06746095_noSWE_seed1_0104_164625 prelim_06746095_noSWE_seed1
# We have a match prelim_06746095_noSWE_seed2_0104_165015 prelim_06746095_noSWE_seed2
# We have a match prelim_07083000_co_swe_snotel_seed0_0304_085533 prelim_07083000_co_swe_snotel_seed0
# We have a match prelim_07083000_co_swe_snotel_seed1_0304_085700 prelim_07083000_co_swe_snotel_seed1
# We have a match prelim_07083000_co_swe_snotel_seed2_0304_085827 prelim_07083000_co_swe_snotel_seed2
# We have a match prelim_07083000_co_swe_ua_seed0_0104_165302 prelim_07083000_co_swe_ua_seed0
# We have a match prelim_07083000_co_swe_ua_seed1_0104_165653 prelim_07083000_co_swe_ua_seed1
# We have a match prelim_07083000_co_swe_ua_seed2_0104_170043 prelim_07083000_co_swe_ua_seed2
# We have a match prelim_07083000_noSWE_seed0_0104_165407 prelim_07083000_noSWE_seed0
# We have a match prelim_07083000_noSWE_seed1_0104_165758 prelim_07083000_noSWE_seed1
# We have a match prelim_07083000_noSWE_seed2_0104_170147 prelim_07083000_noSWE_seed2
# We have a match prelim_09034900_co_swe_snotel_seed0_0304_085955 prelim_09034900_co_swe_snotel_seed0
# We have a match prelim_09034900_co_swe_snotel_seed1_0304_090122 prelim_09034900_co_swe_snotel_seed1
# We have a match prelim_09034900_co_swe_snotel_seed2_0304_090247 prelim_09034900_co_swe_snotel_seed2
# We have a match prelim_09034900_co_swe_ua_seed0_0104_170432 prelim_09034900_co_swe_ua_seed0
# We have a match prelim_09034900_co_swe_ua_seed1_0104_170822 prelim_09034900_co_swe_ua_seed1
# We have a match prelim_09034900_co_swe_ua_seed2_0104_171212 prelim_09034900_co_swe_ua_seed2
# We have a match prelim_09034900_noSWE_seed0_0104_170537 prelim_09034900_noSWE_seed0
# We have a match prelim_09034900_noSWE_seed1_0104_170927 prelim_09034900_noSWE_seed1
# We have a match prelim_09034900_noSWE_seed2_0104_171316 prelim_09034900_noSWE_seed2
# We have a match prelim_09035800_co_swe_snotel_seed0_0304_090413 prelim_09035800_co_swe_snotel_seed0
# We have a match prelim_09035800_co_swe_snotel_seed1_0304_090541 prelim_09035800_co_swe_snotel_seed1
# We have a match prelim_09035800_co_swe_snotel_seed2_0304_090708 prelim_09035800_co_swe_snotel_seed2
# We have a match prelim_09035800_co_swe_ua_seed0_0104_171600 prelim_09035800_co_swe_ua_seed0
# We have a match prelim_09035800_co_swe_ua_seed1_0104_171951 prelim_09035800_co_swe_ua_seed1
# We have a match prelim_09035800_co_swe_ua_seed2_0104_172339 prelim_09035800_co_swe_ua_seed2
# We have a match prelim_09035800_noSWE_seed0_0104_171705 prelim_09035800_noSWE_seed0
# We have a match prelim_09035800_noSWE_seed1_0104_172055 prelim_09035800_noSWE_seed1
# We have a match prelim_09035800_noSWE_seed2_0104_172445 prelim_09035800_noSWE_seed2
# We have a match prelim_09035900_co_swe_snotel_seed0_0304_090834 prelim_09035900_co_swe_snotel_seed0
# We have a match prelim_09035900_co_swe_snotel_seed1_0304_091001 prelim_09035900_co_swe_snotel_seed1
# We have a match prelim_09035900_co_swe_snotel_seed2_0304_091125 prelim_09035900_co_swe_snotel_seed2
# We have a match prelim_09035900_co_swe_ua_seed0_0104_172735 prelim_09035900_co_swe_ua_seed0
# We have a match prelim_09035900_co_swe_ua_seed1_0104_173136 prelim_09035900_co_swe_ua_seed1
# We have a match prelim_09035900_co_swe_ua_seed2_0104_173531 prelim_09035900_co_swe_ua_seed2
# We have a match prelim_09035900_noSWE_seed0_0104_172843 prelim_09035900_noSWE_seed0
# We have a match prelim_09035900_noSWE_seed1_0104_173242 prelim_09035900_noSWE_seed1
# We have a match prelim_09035900_noSWE_seed2_0104_173637 prelim_09035900_noSWE_seed2
# We have a match prelim_09047700_co_swe_snotel_seed0_0304_091249 prelim_09047700_co_swe_snotel_seed0
# We have a match prelim_09047700_co_swe_snotel_seed1_0304_091415 prelim_09047700_co_swe_snotel_seed1
# We have a match prelim_09047700_co_swe_snotel_seed2_0304_091542 prelim_09047700_co_swe_snotel_seed2
# We have a match prelim_09047700_co_swe_ua_seed0_0104_173924 prelim_09047700_co_swe_ua_seed0
# We have a match prelim_09047700_co_swe_ua_seed1_0104_174314 prelim_09047700_co_swe_ua_seed1
# We have a match prelim_09047700_co_swe_ua_seed2_0104_174710 prelim_09047700_co_swe_ua_seed2
# We have a match prelim_09047700_noSWE_seed0_0104_174029 prelim_09047700_noSWE_seed0
# We have a match prelim_09047700_noSWE_seed1_0104_174420 prelim_09047700_noSWE_seed1
# We have a match prelim_09047700_noSWE_seed2_0104_174815 prelim_09047700_noSWE_seed2
# We have a match prelim_09065500_co_swe_snotel_seed0_0304_091709 prelim_09065500_co_swe_snotel_seed0
# We have a match prelim_09065500_co_swe_snotel_seed1_0304_091838 prelim_09065500_co_swe_snotel_seed1
# We have a match prelim_09065500_co_swe_snotel_seed2_0304_092004 prelim_09065500_co_swe_snotel_seed2
# We have a match prelim_09065500_co_swe_ua_seed0_0104_175101 prelim_09065500_co_swe_ua_seed0
# We have a match prelim_09065500_co_swe_ua_seed1_0104_175452 prelim_09065500_co_swe_ua_seed1
# We have a match prelim_09065500_co_swe_ua_seed2_0104_175842 prelim_09065500_co_swe_ua_seed2
# We have a match prelim_09065500_noSWE_seed0_0104_175207 prelim_09065500_noSWE_seed0
# We have a match prelim_09065500_noSWE_seed1_0104_175556 prelim_09065500_noSWE_seed1
# We have a match prelim_09065500_noSWE_seed2_0104_175946 prelim_09065500_noSWE_seed2
# We have a match prelim_09066000_co_swe_snotel_seed0_0304_092132 prelim_09066000_co_swe_snotel_seed0
# We have a match prelim_09066000_co_swe_snotel_seed1_0304_092258 prelim_09066000_co_swe_snotel_seed1
# We have a match prelim_09066000_co_swe_snotel_seed2_0304_092421 prelim_09066000_co_swe_snotel_seed2
# We have a match prelim_09066000_co_swe_ua_seed0_0104_180229 prelim_09066000_co_swe_ua_seed0
# We have a match prelim_09066000_co_swe_ua_seed1_0104_180620 prelim_09066000_co_swe_ua_seed1
# We have a match prelim_09066000_co_swe_ua_seed2_0104_181009 prelim_09066000_co_swe_ua_seed2
# We have a match prelim_09066000_noSWE_seed0_0104_180334 prelim_09066000_noSWE_seed0
# We have a match prelim_09066000_noSWE_seed1_0104_180725 prelim_09066000_noSWE_seed1
# We have a match prelim_09066000_noSWE_seed2_0104_181114 prelim_09066000_noSWE_seed2
# We have a match prelim_09066200_co_swe_snotel_seed0_0304_092545 prelim_09066200_co_swe_snotel_seed0
# We have a match prelim_09066200_co_swe_snotel_seed1_0304_092711 prelim_09066200_co_swe_snotel_seed1
# We have a match prelim_09066200_co_swe_snotel_seed2_0304_092835 prelim_09066200_co_swe_snotel_seed2
# We have a match prelim_09066200_co_swe_ua_seed0_0104_181357 prelim_09066200_co_swe_ua_seed0
# We have a match prelim_09066200_co_swe_ua_seed1_0104_181746 prelim_09066200_co_swe_ua_seed1
# We have a match prelim_09066200_co_swe_ua_seed2_0104_182135 prelim_09066200_co_swe_ua_seed2
# We have a match prelim_09066200_noSWE_seed0_0104_181502 prelim_09066200_noSWE_seed0
# We have a match prelim_09066200_noSWE_seed1_0104_181850 prelim_09066200_noSWE_seed1
# We have a match prelim_09066200_noSWE_seed2_0104_182239 prelim_09066200_noSWE_seed2
# We have a match prelim_09066300_co_swe_snotel_seed0_0304_093001 prelim_09066300_co_swe_snotel_seed0
# We have a match prelim_09066300_co_swe_snotel_seed1_0304_093126 prelim_09066300_co_swe_snotel_seed1
# We have a match prelim_09066300_co_swe_snotel_seed2_0304_093251 prelim_09066300_co_swe_snotel_seed2
# We have a match prelim_09066300_co_swe_ua_seed0_0104_182524 prelim_09066300_co_swe_ua_seed0
# We have a match prelim_09066300_co_swe_ua_seed1_0104_182914 prelim_09066300_co_swe_ua_seed1
# We have a match prelim_09066300_co_swe_ua_seed2_0104_183303 prelim_09066300_co_swe_ua_seed2
# We have a match prelim_09066300_noSWE_seed0_0104_182630 prelim_09066300_noSWE_seed0
# We have a match prelim_09066300_noSWE_seed1_0104_183018 prelim_09066300_noSWE_seed1
# We have a match prelim_09066300_noSWE_seed2_0104_183408 prelim_09066300_noSWE_seed2
# We have a match prelim_09081600_co_swe_snotel_seed0_0304_093417 prelim_09081600_co_swe_snotel_seed0
# We have a match prelim_09081600_co_swe_snotel_seed1_0304_093544 prelim_09081600_co_swe_snotel_seed1
# We have a match prelim_09081600_co_swe_snotel_seed2_0304_093711 prelim_09081600_co_swe_snotel_seed2
# We have a match prelim_09081600_co_swe_ua_seed0_0104_183652 prelim_09081600_co_swe_ua_seed0
# We have a match prelim_09081600_co_swe_ua_seed1_0104_184041 prelim_09081600_co_swe_ua_seed1
# We have a match prelim_09081600_co_swe_ua_seed2_0104_184433 prelim_09081600_co_swe_ua_seed2
# We have a match prelim_09081600_noSWE_seed0_0104_183756 prelim_09081600_noSWE_seed0
# We have a match prelim_09081600_noSWE_seed1_0104_184146 prelim_09081600_noSWE_seed1
# We have a match prelim_09081600_noSWE_seed2_0104_184537 prelim_09081600_noSWE_seed2
# We have a match prelim_09107000_co_swe_snotel_seed0_0304_093836 prelim_09107000_co_swe_snotel_seed0
# We have a match prelim_09107000_co_swe_snotel_seed1_0304_094000 prelim_09107000_co_swe_snotel_seed1
# We have a match prelim_09107000_co_swe_snotel_seed2_0304_094126 prelim_09107000_co_swe_snotel_seed2
# We have a match prelim_09107000_co_swe_ua_seed0_0104_184822 prelim_09107000_co_swe_ua_seed0
# We have a match prelim_09107000_co_swe_ua_seed1_0104_204734 prelim_09107000_co_swe_ua_seed1
# We have a match prelim_09107000_co_swe_ua_seed2_0104_205116 prelim_09107000_co_swe_ua_seed2
# We have a match prelim_09107000_noSWE_seed0_0104_204452 prelim_09107000_noSWE_seed0
# We have a match prelim_09107000_noSWE_seed1_0104_204836 prelim_09107000_noSWE_seed1
# We have a match prelim_09107000_noSWE_seed2_0104_205218 prelim_09107000_noSWE_seed2
# We have a match prelim_09306242_co_swe_snotel_seed0_0304_094250 prelim_09306242_co_swe_snotel_seed0
# We have a match prelim_09306242_co_swe_snotel_seed1_0304_094416 prelim_09306242_co_swe_snotel_seed1
# We have a match prelim_09306242_co_swe_snotel_seed2_0304_094543 prelim_09306242_co_swe_snotel_seed2
# We have a match prelim_09306242_co_swe_ua_seed0_0104_205502 prelim_09306242_co_swe_ua_seed0
# We have a match prelim_09306242_co_swe_ua_seed1_0104_205849 prelim_09306242_co_swe_ua_seed1
# We have a match prelim_09306242_co_swe_ua_seed2_0104_210236 prelim_09306242_co_swe_ua_seed2
# We have a match prelim_09306242_noSWE_seed0_0104_205605 prelim_09306242_noSWE_seed0
# We have a match prelim_09306242_noSWE_seed1_0104_205951 prelim_09306242_noSWE_seed1
# We have a match prelim_09306242_noSWE_seed2_0104_210338 prelim_09306242_noSWE_seed2
# We have a match prelim_09352900_co_swe_snotel_seed0_0304_094708 prelim_09352900_co_swe_snotel_seed0
# We have a match prelim_09352900_co_swe_snotel_seed1_0304_094834 prelim_09352900_co_swe_snotel_seed1
# We have a match prelim_09352900_co_swe_snotel_seed2_0304_094959 prelim_09352900_co_swe_snotel_seed2
# We have a match prelim_09352900_co_swe_ua_seed0_0104_210618 prelim_09352900_co_swe_ua_seed0
# We have a match prelim_09352900_co_swe_ua_seed1_0104_211001 prelim_09352900_co_swe_ua_seed1
# We have a match prelim_09352900_co_swe_ua_seed2_0104_211343 prelim_09352900_co_swe_ua_seed2
# We have a match prelim_09352900_noSWE_seed0_0104_210720 prelim_09352900_noSWE_seed0
# We have a match prelim_09352900_noSWE_seed1_0104_211104 prelim_09352900_noSWE_seed1
# We have a match prelim_09352900_noSWE_seed2_0104_211446 prelim_09352900_noSWE_seed2

# %%
def calculate_nse(observed, simulated):
    """
    Calculate Nash-Sutcliffe Efficiency (NSE) for properly aligned Series.
    
    Parameters:
    - observed: Pandas Series of observed data.
    - simulated: Pandas Series of simulated data.
    
    Returns:
    - NSE value.
    """
    # Ensure both inputs are Series and share a common DatetimeIndex
    if not isinstance(observed, pd.Series) or not isinstance(simulated, pd.Series):
        raise ValueError("Both observed and simulated must be pandas Series with a DatetimeIndex.")
    
    # Intersect indices to ensure alignment
    common_index = observed.index.intersection(simulated.index)
    observed_aligned = observed.loc[common_index].dropna()
    simulated_aligned = simulated.loc[common_index].dropna()

    if not observed_aligned.empty and not simulated_aligned.empty:
        mean_observed = observed_aligned.mean()
        numerator = ((observed_aligned - simulated_aligned) ** 2).sum()
        denominator = ((observed_aligned - mean_observed) ** 2).sum()
        nse = 1 - (numerator / denominator)
        return nse
    else:
        return np.nan  # Indicate misalignment or empty data

# %%
def plot_site_time_series_multi_model_nse(data_dict, site_id):
    """
    Plot the time series for an individual site with NSE values for multiple models.
    
    Parameters:
    - data_dict: Dictionary containing the data.
    - site_id: Site ID to plot.
    """
    plt.figure(figsize=(6, 4))

    # Initial vertical position for the first NSE annotation
    vertical_position = 0.95
    
    # Vertical offset to stack annotations
    vertical_offset = 0.1
    
    model_colors = {
        'noSWE': ('pink', 'darkred'),
        'co_swe_ua': ('lightcyan', 'cyan'),
        'co_swe_snotel': ('lightsteelblue', 'blue')
    }
    model_style = {
        'noSWE': "-",
        'co_swe_ua': "--",
        'co_swe_snotel': "-."
    }
    # Iterate through model types and plot each
    for model_type in ['noSWE', 'co_swe_ua', 'co_swe_snotel']:
        ensemble_sim_data = []
        for seed, data in data_dict[site_id][model_type].items():
            qobs_obs = data['QObs(mm/d)_obs'].to_pandas()
            qobs_sim = data['QObs(mm/d)_sim'].to_pandas()
            plt.plot(qobs_sim.index, qobs_sim, 
                     color=model_colors[model_type][0], linewidth=0.5, ls=model_style[model_type])
            ensemble_sim_data.append(qobs_sim)
            
        ensemble_mean = pd.concat(ensemble_sim_data, axis=1).mean(axis=1)
        plt.plot(ensemble_mean.index, ensemble_mean, color=model_colors[model_type][1], 
                 label=f'{model_type}', linewidth=2, ls=model_style[model_type])

        # Calculate NSE for the ensemble mean and adjust text placement
        # Given qobs_obs structure, directly using the single unnamed column for observed data
        qobs_obs_series = qobs_obs[0]
        nse_value = calculate_nse(qobs_obs_series, ensemble_mean)
        plt.text(0.05, vertical_position, f'{model_type} NSE: {nse_value:.2f}', 
                 transform=plt.gca().transAxes, fontsize=9, verticalalignment='top', 
                 bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.5))
        
        # Update vertical_position for the next annotation
        vertical_position -= vertical_offset

    plt.plot(qobs_obs.index, qobs_obs, color='black', label='Observed', linewidth=1.5)
    plt.title(f'Time Series for Site {site_id}')
    plt.xlabel('Date')
    plt.xticks(rotation=45, ha='right')
    plt.ylabel('QObs (mm/d)')
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
# Example usage
# Assuming 'data_dict' is already filled with your data
plot_site_time_series_multi_model_nse(data_dict, '09352900')

# %%
# Step 1: Extract NSE Values
nse_values = {'Model': [], 'NSE': []}
for site_id, models in data_dict.items():
    if site_id == "09306242":
        continue
    for model_type, seeds in models.items():
        for seed, results in seeds.items():
            nse_value = results['NSE']  # Directly accessing the NSE value
            nse_values['Model'].append(model_type)
            nse_values['NSE'].append(nse_value)

# Step 2: Prepare the Data for Plotting
nse_df = pd.DataFrame(nse_values)

# Step 3: Create Box Plots
plt.figure(figsize=(6, 4))
sns.boxplot(x='Model', y='NSE', data=nse_df)

plt.title('Distribution of Ensemble Mean NSE Values by Model')
plt.xlabel('Model Type')
plt.ylabel('NSE Value')
plt.ylim(-0.5, 1)  # Adjust the Y-axis limits as necessary

plt.show()

# %%
for site_id, models in data_dict.items():
    plot_site_time_series_multi_model_nse(data_dict, site_id)
